# %% [markdown]
# # Experiment Notebook: Money Markets

# %% [markdown]
# # Table of Contents
# * [Experiment Summary](#Experiment-Summary)
# * [Experiment Assumptions](#Experiment-Assumptions)
# * [Experiment Setup](#Experiment-Setup)
# * [Analysis 1: ...](#Analysis-1:-...)

# %% [markdown]
# # Experiment Summary
#
# The purpose of this notebook is to...
#
# # Experiment Assumptions
#
# See [assumptions document](../../ASSUMPTIONS.md) for further details.

# %% [markdown]
# # Experiment Setup
#
# We begin with several experiment-notebook-level preparatory setup operations:
#
# * Import relevant dependencies
# * Import relevant experiment templates
# * Create copies of experiments
# * Configure and customize experiments
#
# Analysis-specific setup operations are handled in their respective notebook sections.

# %%
# Import the setup module:
# * sets up the Python path
# * runs shared notebook configuration methods, such as loading IPython modules
import setup

import copy
import logging
import numpy as np
import pandas as pd
import plotly.express as px

import experiments.notebooks.visualizations as visualizations
from experiments.run import run
from experiments.utils import display_code
# Out:
# time: 395 ms (started: 2022-08-02 15:46:25 +02:00)

# %%
# Enable/disable logging
logger = logging.getLogger()
logger.disabled = False
# Out:
# time: 11.8 ms (started: 2022-08-02 15:46:26 +02:00)

# %%
# Import experiment templates
import experiments.default_experiment as default_experiment
# Out:
# time: 12.8 ms (started: 2022-08-02 15:46:26 +02:00)

# %%
# Create a simulation for each analysis
simulation_1 = copy.deepcopy(default_experiment.experiment.simulations[0])
# Out:
# time: 12.4 ms (started: 2022-08-02 15:46:26 +02:00)

# %%
# Experiment configuration
simulation_1.model.initial_state.update({})

simulation_1.model.params.update({})
# Out:
# time: 11.8 ms (started: 2022-08-02 15:46:26 +02:00)

# %% [markdown]
# # Analysis 1: Money Market Supply and Borrow Rates

# %% [markdown]
# {Analysis Description}

# %%
# Analysis-specific setup
# Out:
# time: 13 ms (started: 2022-08-02 15:46:26 +02:00)

# %%
# Experiment execution
df, exceptions = run(simulation_1)
# Out:
# 2022-08-02 15:46:26,492 - root - INFO - Running experiment
# 2022-08-02 15:46:26,575 - root - INFO - Setting up initial state
# 2022-08-02 15:46:26,613 - root - INFO - Starting simulation 0 / run 0 / subset 0
# 2022-08-02 15:46:28,586 - root - INFO - Experiment complete in 2.0935380458831787 seconds
# 2022-08-02 15:46:28,587 - root - INFO - Post-processing results
# 2022-08-02 15:46:29,071 - root - INFO - Post-processing complete in 0.48483729362487793 seconds
# time: 2.59 s (started: 2022-08-02 15:46:26 +02:00)

# %%
# Post-processing and visualizations
# Out:
# time: 18.6 ms (started: 2022-08-02 15:46:29 +02:00)

# %%
df['fei_money_market_pcv_deposit_balance'].plot()
# Out:
# time: 61.4 ms (started: 2022-08-02 15:46:29 +02:00)

# %%
df['fei_money_market_utilization'].plot()
# Out:
# time: 66.1 ms (started: 2022-08-02 15:47:52 +02:00)

# %%
df['fei_money_market_borrowed'].plot()
# Out:
# time: 58.3 ms (started: 2022-08-02 15:46:29 +02:00)

# %%
df[['fei_money_market_supply_rate', 'fei_money_market_borrow_rate']].plot()
# Out:
# time: 74.4 ms (started: 2022-08-02 15:46:29 +02:00)

# %%
df['fei_money_market_pcv_deposit_yield_rate'].plot()
# Out:
# time: 92 ms (started: 2022-08-02 15:47:48 +02:00)

# %% [markdown]
# Inspect the evolution of how much was borrowed to understand the change in borrow and lending (supply) rates
